# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ### Analysing Age

# %%
sns.displot(df['Age'],kde = True)

# %% [markdown]
# #### Most of the data is around Age of 40 to 70.

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\ACT\AppData\Local\Temp\ipykernel_13724\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### Distibution PLot for Numerical Columns

# %%
sns.displot(df['RestingBP'],kde = True, color = 'green')

# %% [markdown]
# #### Most of the patients have RestingBP around 120 and above

# %%
sns.displot(df['Cholesterol'],kde = True, color = 'green')

# %% [markdown]
# #### Here also the distribution is Normal but we have an outlier as most of the patients are having 0 Cholesterol.

# %%
sns.displot(df['FastingBS'],kde = True, color = 'green')

# %%
sns.displot(df['MaxHR'],kde = True, color = 'green')

# %%
#### Most of the patients have MaxHR b/w 120 to 160

# %%
sns.displot(df['Oldpeak'],kde = True, color = 'green')

# %% [markdown]
# #### Oldpeak is a measured value in depression
